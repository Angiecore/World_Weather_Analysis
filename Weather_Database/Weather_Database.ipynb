# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
## Retrieve the nearest city

#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 728

# %%
## OpenWeatherMap API Key

#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | irtyshskiy
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | samarai
# Processing Record 4 of Set 1 | jojoima
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | ilulissat
# Processing Record 7 of Set 1 | yar-sale
# Processing Record 8 of Set 1 | magadan
# Processing Record 9 of Set 1 | mount gambier
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | vostok
# Processing Record 12 of Set 1 | port hardy
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | saskylakh
# Processing Record 16 of Set 1 | fort saint john
# City not found. Skipping...
# Processing Record 17 of Set 1 | mahebourg
# Processing Record 18 of Set 1 | inuvik
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | serenje
# Processing Record 21 of Set 1 | oberndorf
# Processing Record 22 of Set 1 | port macquarie
# Processing Record 23 of Set 1 | tiksi
# Processing Record 24 of Set 1 | pisco
# Processing Record 25 of Set 1 | vila franca do campo
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | harper
# Processing Record 29 of Set 1 | saint-philippe
# Processing Record 30 of Set 1 | yashalta
# Processing Record 31 of Set 1 | bluff
# Processing Record 32 of Set 1 | champasak
# Processing Record 33 of Set 1 | qaanaaq
# Processing Record 34 of Set 1 | port lincoln
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 1 | labuhan
# Processing Record 41 of Set 1 | bonthe
# Processing Record 42 of Set 1 | leningradskiy
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | meridian
# Processing Record 45 of Set 1 | clyde river
# Processing Record 46 of Set 1 | aksu
# Processing Record 47 of Set 1 | san quintin
# Processing Record 48 of Set 1 | port elizabeth
# Processing Record 49 of Set 1 | saint-joseph
# Processing Record 50 of Set 1 | half moon bay
# Processing Record 1 of Set 2 | tautira
# Processing Record 2 of Set 2 | andenes
# Processing Record 3 of Set 2 | iralaya
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | lisa
# Processing Record 6 of Set 2 | albany
# Processing Record 7 of Set 2 | porto novo
# Processing Record 8 of Set 2 | te anau
# Processing Record 9 of Set 2 | conde
# Processing Record 10 of Set 2 | gorkovskoye
# City not found. Skipping...
# Processing Record 11 of Set 2 | iberia
# Processing Record 12 of Set 2 | cap malheureux
# Processing Record 13 of Set 2 | skagastrond
# City not found. Skipping...
# Processing Record 14 of Set 2 | verkhnyaya sinyachikha
# Processing Record 15 of Set 2 | bredasdorp
# Processing Record 16 of Set 2 | harda
# Processing Record 17 of Set 2 | hobart
# Processing Record 18 of Set 2 | iqaluit
# Processing Record 19 of Set 2 | geraldton
# Processing Record 20 of Set 2 | apac
# Processing Record 21 of Set 2 | nicoya
# Processing Record 22 of Set 2 | punta arenas
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | khatanga
# Processing Record 25 of Set 2 | sigli
# Processing Record 26 of Set 2 | marivan
# Processing Record 27 of Set 2 | cabra
# Processing Record 28 of Set 2 | isangel
# Processing Record 29 of Set 2 | disa
# Processing Record 30 of Set 2 | hilo
# Processing Record 31 of Set 2 | ponta do sol
# Processing Record 32 of Set 2 | kaitangata
# Processing Record 33 of Set 2 | chokurdakh
# Processing Record 34 of Set 2 | broome
# Processing Record 35 of Set 2 | trairi
# Processing Record 36 of Set 2 | torbay
# Processing Record 37 of Set 2 | kadoma
# Processing Record 38 of Set 2 | hamilton
# Processing Record 39 of Set 2 | la ronge
# Processing Record 40 of Set 2 | dikson
# Processing Record 41 of Set 2 | lansing
# Processing Record 42 of Set 2 | hithadhoo
# Processing Record 43 of Set 2 | upernavik
# Processing Record 44 of Set 2 | kiunga
# Processing Record 45 of Set 2 | balkanabat
# Processing Record 46 of Set 2 | karratha
# Processing Record 47 of Set 2 | jewar
# Processing Record 48 of Set 2 | georgetown
# Processing Record 49 of Set 2 | leh
# Processing Record 50 of Set 2 | tuatapere
# Processing Record 1 of Set 3 | aklavik
# Processing Record 2 of Set 3 | teluknaga
# Processing Record 3 of Set 3 | beringovskiy
# Processing Record 4 of Set 3 | heihe
# Processing Record 5 of Set 3 | acapulco
# Processing Record 6 of Set 3 | cayenne
# Processing Record 7 of Set 3 | severo-kurilsk
# Processing Record 8 of Set 3 | cape town
# Processing Record 9 of Set 3 | juxtlahuaca
# Processing Record 10 of Set 3 | karakol
# Processing Record 11 of Set 3 | kushima
# Processing Record 12 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 3 | balabac
# Processing Record 14 of Set 3 | arraial do cabo
# Processing Record 15 of Set 3 | jimeta
# Processing Record 16 of Set 3 | marzuq
# Processing Record 17 of Set 3 | cabo san lucas
# Processing Record 18 of Set 3 | megion
# Processing Record 19 of Set 3 | biloela
# Processing Record 20 of Set 3 | anadyr
# Processing Record 21 of Set 3 | kloulklubed
# Processing Record 22 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 3 | honghu
# Processing Record 24 of Set 3 | tasiilaq
# Processing Record 25 of Set 3 | coihaique
# Processing Record 26 of Set 3 | sao felix do xingu
# Processing Record 27 of Set 3 | new norfolk
# Processing Record 28 of Set 3 | cuncolim
# Processing Record 29 of Set 3 | jonacatepec
# Processing Record 30 of Set 3 | mikropolis
# Processing Record 31 of Set 3 | slave lake
# Processing Record 32 of Set 3 | abiy adi
# City not found. Skipping...
# Processing Record 33 of Set 3 | hirara
# Processing Record 34 of Set 3 | tura
# Processing Record 35 of Set 3 | altay
# Processing Record 36 of Set 3 | saint george
# Processing Record 37 of Set 3 | chapais
# Processing Record 38 of Set 3 | pangnirtung
# Processing Record 39 of Set 3 | kumluca
# Processing Record 40 of Set 3 | agua verde
# Processing Record 41 of Set 3 | babu
# Processing Record 42 of Set 3 | provideniya
# Processing Record 43 of Set 3 | ternate
# Processing Record 44 of Set 3 | birjand
# Processing Record 45 of Set 3 | tarecuato
# Processing Record 46 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 3 | nhulunbuy
# Processing Record 48 of Set 3 | vikulovo
# Processing Record 49 of Set 3 | mar del plata
# Processing Record 50 of Set 3 | yuanli
# Processing Record 1 of Set 4 | scottsburgh
# City not found. Skipping...
# Processing Record 2 of Set 4 | castro
# Processing Record 3 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 4 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 4 | mayor pablo lagerenza
# Processing Record 6 of Set 4 | kerema
# Processing Record 7 of Set 4 | codrington
# Processing Record 8 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 9 of Set 4 | alofi
# Processing Record 10 of Set 4 | taoudenni
# Processing Record 11 of Set 4 | namatanai
# Processing Record 12 of Set 4 | faanui
# Processing Record 13 of Set 4 | nanortalik
# Processing Record 14 of Set 4 | seguela
# Processing Record 15 of Set 4 | klaksvik
# Processing Record 16 of Set 4 | willmar
# Processing Record 17 of Set 4 | kodiak
# Processing Record 18 of Set 4 | ostrovnoy
# Processing Record 19 of Set 4 | thompson
# Processing Record 20 of Set 4 | marawi
# Processing Record 21 of Set 4 | fortuna
# Processing Record 22 of Set 4 | fairbanks
# Processing Record 23 of Set 4 | dunedin
# Processing Record 24 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 25 of Set 4 | raudeberg
# Processing Record 26 of Set 4 | sitka
# Processing Record 27 of Set 4 | lusambo
# Processing Record 28 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 29 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 30 of Set 4 | sao joao da barra
# Processing Record 31 of Set 4 | cidreira
# Processing Record 32 of Set 4 | hambantota
# Processing Record 33 of Set 4 | kodinsk
# Processing Record 34 of Set 4 | college
# Processing Record 35 of Set 4 | ozgon
# City not found. Skipping...
# Processing Record 36 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 4 | noyabrsk
# Processing Record 38 of Set 4 | katsuura
# Processing Record 39 of Set 4 | carnarvon
# Processing Record 40 of Set 4 | khudumelapye
# Processing Record 41 of Set 4 | bathsheba
# Processing Record 42 of Set 4 | nikolayevsk-na-amure
# Processing Record 43 of Set 4 | borogontsy
# Processing Record 44 of Set 4 | bengkulu
# Processing Record 45 of Set 4 | longyearbyen
# Processing Record 46 of Set 4 | ketchikan
# Processing Record 47 of Set 4 | esperance
# Processing Record 48 of Set 4 | menongue
# Processing Record 49 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 4 | rizhao
# Processing Record 1 of Set 5 | trelew
# Processing Record 2 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 3 of Set 5 | santa isabel
# Processing Record 4 of Set 5 | konskie
# Processing Record 5 of Set 5 | jiuquan
# Processing Record 6 of Set 5 | sira
# Processing Record 7 of Set 5 | haikou
# Processing Record 8 of Set 5 | airai
# Processing Record 9 of Set 5 | kangaatsiaq
# Processing Record 10 of Set 5 | abu samrah
# Processing Record 11 of Set 5 | camacha
# Processing Record 12 of Set 5 | glyadyanskoye
# Processing Record 13 of Set 5 | fare
# Processing Record 14 of Set 5 | norman wells
# Processing Record 15 of Set 5 | big spring
# Processing Record 16 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 5 | najran
# Processing Record 18 of Set 5 | yagoua
# Processing Record 19 of Set 5 | roald
# Processing Record 20 of Set 5 | westpunt
# City not found. Skipping...
# Processing Record 21 of Set 5 | lerwick
# Processing Record 22 of Set 5 | sisimiut
# Processing Record 23 of Set 5 | barrow
# Processing Record 24 of Set 5 | jalu
# Processing Record 25 of Set 5 | lavrentiya
# Processing Record 26 of Set 5 | port-cartier
# Processing Record 27 of Set 5 | kahului
# Processing Record 28 of Set 5 | poum
# Processing Record 29 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 5 | karpogory
# Processing Record 31 of Set 5 | jumla
# Processing Record 32 of Set 5 | axim
# Processing Record 33 of Set 5 | nikki
# Processing Record 34 of Set 5 | puerto ayora
# Processing Record 35 of Set 5 | oistins
# Processing Record 36 of Set 5 | sharjah
# Processing Record 37 of Set 5 | san pedro
# Processing Record 38 of Set 5 | terney
# Processing Record 39 of Set 5 | fuling
# Processing Record 40 of Set 5 | bosaso
# Processing Record 41 of Set 5 | lagoa
# Processing Record 42 of Set 5 | aranos
# Processing Record 43 of Set 5 | vardo
# Processing Record 44 of Set 5 | alyangula
# Processing Record 45 of Set 5 | ibiruba
# Processing Record 46 of Set 5 | shache
# Processing Record 47 of Set 5 | anahuac
# Processing Record 48 of Set 5 | boralday
# Processing Record 49 of Set 5 | east london
# Processing Record 50 of Set 5 | kipini
# Processing Record 1 of Set 6 | belyy yar
# Processing Record 2 of Set 6 | sechura
# Processing Record 3 of Set 6 | port alfred
# Processing Record 4 of Set 6 | padang
# Processing Record 5 of Set 6 | zhigansk
# Processing Record 6 of Set 6 | quatre cocos
# Processing Record 7 of Set 6 | great bend
# Processing Record 8 of Set 6 | tuktoyaktuk
# Processing Record 9 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 6 | portland
# Processing Record 11 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 6 | sucua
# Processing Record 13 of Set 6 | isiro
# Processing Record 14 of Set 6 | port keats
# Processing Record 15 of Set 6 | tocopilla
# Processing Record 16 of Set 6 | novokayakent
# Processing Record 17 of Set 6 | bethel
# Processing Record 18 of Set 6 | lorengau
# Processing Record 19 of Set 6 | tchibanga
# Processing Record 20 of Set 6 | spearfish
# Processing Record 21 of Set 6 | hofn
# Processing Record 22 of Set 6 | yangambi
# Processing Record 23 of Set 6 | podosinovets
# Processing Record 24 of Set 6 | zhezkazgan
# Processing Record 25 of Set 6 | prince rupert
# Processing Record 26 of Set 6 | yakovlevka
# Processing Record 27 of Set 6 | fort-shevchenko
# Processing Record 28 of Set 6 | derzhavinsk
# Processing Record 29 of Set 6 | yunjinghong
# City not found. Skipping...
# Processing Record 30 of Set 6 | lebu
# Processing Record 31 of Set 6 | victoria
# Processing Record 32 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 6 | tumbagaan
# Processing Record 34 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 6 | virtsu
# Processing Record 36 of Set 6 | itamaraca
# Processing Record 37 of Set 6 | tarnos
# Processing Record 38 of Set 6 | ouro preto do oeste
# Processing Record 39 of Set 6 | marsh harbour
# Processing Record 40 of Set 6 | kamyshlov
# Processing Record 41 of Set 6 | abu dhabi
# Processing Record 42 of Set 6 | bontang
# Processing Record 43 of Set 6 | chumikan
# Processing Record 44 of Set 6 | balykshi
# Processing Record 45 of Set 6 | necochea
# Processing Record 46 of Set 6 | manggar
# Processing Record 47 of Set 6 | yumen
# Processing Record 48 of Set 6 | dingle
# Processing Record 49 of Set 6 | longonjo
# Processing Record 50 of Set 6 | peace river
# Processing Record 1 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 7 | navashino
# Processing Record 3 of Set 7 | quimper
# Processing Record 4 of Set 7 | salalah
# Processing Record 5 of Set 7 | banda aceh
# Processing Record 6 of Set 7 | morondava
# Processing Record 7 of Set 7 | tabora
# Processing Record 8 of Set 7 | plettenberg bay
# Processing Record 9 of Set 7 | kruisfontein
# Processing Record 10 of Set 7 | maumere
# Processing Record 11 of Set 7 | mahina
# Processing Record 12 of Set 7 | yatou
# Processing Record 13 of Set 7 | madera
# Processing Record 14 of Set 7 | khormuj
# City not found. Skipping...
# Processing Record 15 of Set 7 | ahipara
# Processing Record 16 of Set 7 | panaba
# Processing Record 17 of Set 7 | bambous virieux
# Processing Record 18 of Set 7 | maniitsoq
# Processing Record 19 of Set 7 | maragogi
# Processing Record 20 of Set 7 | nikolskoye
# Processing Record 21 of Set 7 | aripuana
# Processing Record 22 of Set 7 | ostashkov
# Processing Record 23 of Set 7 | palmer
# Processing Record 24 of Set 7 | vila velha
# Processing Record 25 of Set 7 | ukiah
# Processing Record 26 of Set 7 | paragominas
# Processing Record 27 of Set 7 | beira
# Processing Record 28 of Set 7 | buala
# Processing Record 29 of Set 7 | puerto del rosario
# Processing Record 30 of Set 7 | brigantine
# Processing Record 31 of Set 7 | pevek
# Processing Record 32 of Set 7 | del rio
# Processing Record 33 of Set 7 | jaipur hat
# City not found. Skipping...
# Processing Record 34 of Set 7 | dawei
# Processing Record 35 of Set 7 | cherskiy
# Processing Record 36 of Set 7 | pacifica
# Processing Record 37 of Set 7 | ubauro
# Processing Record 38 of Set 7 | dien bien
# City not found. Skipping...
# Processing Record 39 of Set 7 | sukhobuzimskoye
# Processing Record 40 of Set 7 | tingrela
# City not found. Skipping...
# Processing Record 41 of Set 7 | saldanha
# Processing Record 42 of Set 7 | kavieng
# Processing Record 43 of Set 7 | phan thiet
# Processing Record 44 of Set 7 | mayo
# Processing Record 45 of Set 7 | tucuman
# Processing Record 46 of Set 7 | tommot
# Processing Record 47 of Set 7 | buffalo
# Processing Record 48 of Set 7 | balod
# Processing Record 49 of Set 7 | yining
# Processing Record 50 of Set 7 | westport
# Processing Record 1 of Set 8 | sunland park
# Processing Record 2 of Set 8 | luderitz
# Processing Record 3 of Set 8 | starkville
# Processing Record 4 of Set 8 | hami
# Processing Record 5 of Set 8 | waddan
# Processing Record 6 of Set 8 | beyneu
# Processing Record 7 of Set 8 | morwell
# Processing Record 8 of Set 8 | haines junction
# Processing Record 9 of Set 8 | rovaniemi
# Processing Record 10 of Set 8 | poopo
# Processing Record 11 of Set 8 | ribeira grande
# Processing Record 12 of Set 8 | ulladulla
# Processing Record 13 of Set 8 | arroyo
# Processing Record 14 of Set 8 | olafsvik
# Processing Record 15 of Set 8 | uyuni
# Processing Record 16 of Set 8 | kamenka
# Processing Record 17 of Set 8 | halifax
# Processing Record 18 of Set 8 | karacakoy
# Processing Record 19 of Set 8 | zanjan
# Processing Record 20 of Set 8 | hualmay
# Processing Record 21 of Set 8 | hasaki
# Processing Record 22 of Set 8 | henties bay
# Processing Record 23 of Set 8 | neiafu
# Processing Record 24 of Set 8 | miami beach
# Processing Record 25 of Set 8 | luz
# Processing Record 26 of Set 8 | mahajanga
# Processing Record 27 of Set 8 | watertown
# Processing Record 28 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 8 | clarence town
# Processing Record 30 of Set 8 | quelimane
# Processing Record 31 of Set 8 | villa carlos paz
# Processing Record 32 of Set 8 | tokur
# Processing Record 33 of Set 8 | kapit
# Processing Record 34 of Set 8 | tricase
# Processing Record 35 of Set 8 | yantzaza
# Processing Record 36 of Set 8 | kigorobya
# Processing Record 37 of Set 8 | polunochnoye
# Processing Record 38 of Set 8 | burica
# City not found. Skipping...
# Processing Record 39 of Set 8 | los llanos de aridane
# Processing Record 40 of Set 8 | yerazgavors
# Processing Record 41 of Set 8 | salinopolis
# Processing Record 42 of Set 8 | duz
# City not found. Skipping...
# Processing Record 43 of Set 8 | cascais
# Processing Record 44 of Set 8 | lethem
# Processing Record 45 of Set 8 | honiara
# Processing Record 46 of Set 8 | lata
# Processing Record 47 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 48 of Set 8 | vao
# Processing Record 49 of Set 8 | makasar
# Processing Record 50 of Set 8 | batticaloa
# Processing Record 1 of Set 9 | valle de allende
# Processing Record 2 of Set 9 | aberdour
# Processing Record 3 of Set 9 | ust-kuyga
# Processing Record 4 of Set 9 | gimli
# Processing Record 5 of Set 9 | babanusah
# City not found. Skipping...
# Processing Record 6 of Set 9 | san juan
# Processing Record 7 of Set 9 | nadlac
# Processing Record 8 of Set 9 | luanda
# Processing Record 9 of Set 9 | pedasi
# Processing Record 10 of Set 9 | segezha
# Processing Record 11 of Set 9 | viedma
# Processing Record 12 of Set 9 | grobina
# Processing Record 13 of Set 9 | bierbeek
# Processing Record 14 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 9 | laguna
# Processing Record 16 of Set 9 | inhambane
# Processing Record 17 of Set 9 | sao filipe
# Processing Record 18 of Set 9 | garowe
# Processing Record 19 of Set 9 | skibbereen
# Processing Record 20 of Set 9 | thaba-tseka
# Processing Record 21 of Set 9 | bacolod
# Processing Record 22 of Set 9 | guerrero negro
# Processing Record 23 of Set 9 | pithoragarh
# Processing Record 24 of Set 9 | namibe
# Processing Record 25 of Set 9 | skjeberg
# Processing Record 26 of Set 9 | narsaq
# Processing Record 27 of Set 9 | bouca
# Processing Record 28 of Set 9 | indiana
# Processing Record 29 of Set 9 | gizo
# Processing Record 30 of Set 9 | vestmanna
# Processing Record 31 of Set 9 | jos
# Processing Record 32 of Set 9 | sorland
# Processing Record 33 of Set 9 | leshukonskoye
# Processing Record 34 of Set 9 | chuy
# Processing Record 35 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 9 | lexington park
# Processing Record 37 of Set 9 | esil
# Processing Record 38 of Set 9 | bismarck
# Processing Record 39 of Set 9 | garissa
# Processing Record 40 of Set 9 | suntar
# Processing Record 41 of Set 9 | sinnamary
# Processing Record 42 of Set 9 | alvorada
# Processing Record 43 of Set 9 | colac
# Processing Record 44 of Set 9 | asau
# Processing Record 45 of Set 9 | mattru
# Processing Record 46 of Set 9 | auki
# Processing Record 47 of Set 9 | tlaxco
# Processing Record 48 of Set 9 | ancud
# Processing Record 49 of Set 9 | sheltozero
# Processing Record 50 of Set 9 | challapata
# Processing Record 1 of Set 10 | kjollefjord
# Processing Record 2 of Set 10 | san patricio
# Processing Record 3 of Set 10 | kieta
# Processing Record 4 of Set 10 | biltine
# Processing Record 5 of Set 10 | ekhabi
# Processing Record 6 of Set 10 | lucea
# Processing Record 7 of Set 10 | shalinskoye
# Processing Record 8 of Set 10 | boyuibe
# Processing Record 9 of Set 10 | dali
# Processing Record 10 of Set 10 | alexandria
# Processing Record 11 of Set 10 | izumo
# Processing Record 12 of Set 10 | berlevag
# Processing Record 13 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 14 of Set 10 | kavaratti
# Processing Record 15 of Set 10 | yanji
# Processing Record 16 of Set 10 | tromso
# Processing Record 17 of Set 10 | el segundo
# Processing Record 18 of Set 10 | rochelle
# Processing Record 19 of Set 10 | vanderhoof
# Processing Record 20 of Set 10 | bara
# Processing Record 21 of Set 10 | faya
# Processing Record 22 of Set 10 | emerald
# Processing Record 23 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 24 of Set 10 | nongan
# Processing Record 25 of Set 10 | machakos
# Processing Record 26 of Set 10 | la palma
# Processing Record 27 of Set 10 | kutulik
# Processing Record 28 of Set 10 | dafeng
# Processing Record 29 of Set 10 | tambacounda
# Processing Record 30 of Set 10 | atambua
# Processing Record 31 of Set 10 | chengde
# Processing Record 32 of Set 10 | marystown
# Processing Record 33 of Set 10 | gat
# Processing Record 34 of Set 10 | north bend
# Processing Record 35 of Set 10 | kilindoni
# Processing Record 36 of Set 10 | antequera
# Processing Record 37 of Set 10 | tecoanapa
# Processing Record 38 of Set 10 | ziniare
# Processing Record 39 of Set 10 | springbok
# Processing Record 40 of Set 10 | buchanan
# Processing Record 41 of Set 10 | ganta
# Processing Record 42 of Set 10 | timra
# Processing Record 43 of Set 10 | ogulin
# Processing Record 44 of Set 10 | oussouye
# Processing Record 45 of Set 10 | san javier
# Processing Record 46 of Set 10 | rio cauto
# Processing Record 47 of Set 10 | varkkallai
# Processing Record 48 of Set 10 | peniche
# Processing Record 49 of Set 10 | weligama
# Processing Record 50 of Set 10 | hit
# Processing Record 1 of Set 11 | grindavik
# Processing Record 2 of Set 11 | luwuk
# Processing Record 3 of Set 11 | egvekinot
# Processing Record 4 of Set 11 | sistranda
# Processing Record 5 of Set 11 | winnemucca
# Processing Record 6 of Set 11 | dudinka
# Processing Record 7 of Set 11 | flinders
# Processing Record 8 of Set 11 | jodar
# Processing Record 9 of Set 11 | mehamn
# Processing Record 10 of Set 11 | krasnoselkup
# Processing Record 11 of Set 11 | kindu
# Processing Record 12 of Set 11 | baruun-urt
# Processing Record 13 of Set 11 | alanya
# Processing Record 14 of Set 11 | matara
# Processing Record 15 of Set 11 | tilichiki
# Processing Record 16 of Set 11 | kiama
# Processing Record 17 of Set 11 | hohhot
# Processing Record 18 of Set 11 | matamoros
# Processing Record 19 of Set 11 | sibolga
# Processing Record 20 of Set 11 | saint-pierre
# Processing Record 21 of Set 11 | darnah
# Processing Record 22 of Set 11 | tsiroanomandidy
# Processing Record 23 of Set 11 | taos
# Processing Record 24 of Set 11 | buchlovice
# Processing Record 25 of Set 11 | rocha
# Processing Record 26 of Set 11 | nortelandia
# Processing Record 27 of Set 11 | batagay
# Processing Record 28 of Set 11 | japura
# Processing Record 29 of Set 11 | sovetskaya gavan
# Processing Record 30 of Set 11 | progreso
# Processing Record 31 of Set 11 | port augusta
# Processing Record 32 of Set 11 | keti bandar
# Processing Record 33 of Set 11 | evensk
# Processing Record 34 of Set 11 | moussoro
# Processing Record 35 of Set 11 | zhongshu
# Processing Record 36 of Set 11 | mabama
# Processing Record 37 of Set 11 | vanimo
# Processing Record 38 of Set 11 | kahama
# Processing Record 39 of Set 11 | murygino
# Processing Record 40 of Set 11 | udachnyy
# Processing Record 41 of Set 11 | richards bay
# Processing Record 42 of Set 11 | havoysund
# Processing Record 43 of Set 11 | luganville
# Processing Record 44 of Set 11 | tual
# Processing Record 45 of Set 11 | turukhansk
# Processing Record 46 of Set 11 | kuytun
# Processing Record 47 of Set 11 | yenagoa
# Processing Record 48 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 49 of Set 11 | ambatofinandrahana
# Processing Record 50 of Set 11 | komsomolskiy
# Processing Record 1 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 12 | sur
# Processing Record 3 of Set 12 | cockburn town
# Processing Record 4 of Set 12 | praia da vitoria
# Processing Record 5 of Set 12 | kitui
# Processing Record 6 of Set 12 | altamont
# Processing Record 7 of Set 12 | dickinson
# Processing Record 8 of Set 12 | nome
# Processing Record 9 of Set 12 | ponta delgada
# Processing Record 10 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 12 | whitehorse
# Processing Record 12 of Set 12 | alice springs
# Processing Record 13 of Set 12 | ziezmariai
# Processing Record 14 of Set 12 | kontagora
# Processing Record 15 of Set 12 | calabozo
# Processing Record 16 of Set 12 | byron bay
# Processing Record 17 of Set 12 | shelabolikha
# Processing Record 18 of Set 12 | goderich
# Processing Record 19 of Set 12 | zhangjiakou
# Processing Record 20 of Set 12 | taltal
# Processing Record 21 of Set 12 | springfield
# Processing Record 22 of Set 12 | the valley
# Processing Record 23 of Set 12 | natal
# Processing Record 24 of Set 12 | deputatskiy
# Processing Record 25 of Set 12 | grand gaube
# Processing Record 26 of Set 12 | albufeira
# Processing Record 27 of Set 12 | caravelas
# Processing Record 28 of Set 12 | muros
# Processing Record 29 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 30 of Set 12 | neyshabur
# Processing Record 31 of Set 12 | nuevitas
# Processing Record 32 of Set 12 | andselv
# City not found. Skipping...
# Processing Record 33 of Set 12 | muzhi
# Processing Record 34 of Set 12 | trincomalee
# Processing Record 35 of Set 12 | mosquera
# Processing Record 36 of Set 12 | hobyo
# Processing Record 37 of Set 12 | hakodate
# Processing Record 38 of Set 12 | calvinia
# Processing Record 39 of Set 12 | talnakh
# Processing Record 40 of Set 12 | southbridge
# Processing Record 41 of Set 12 | hilton head island
# Processing Record 42 of Set 12 | ihosy
# Processing Record 43 of Set 12 | pacific grove
# Processing Record 44 of Set 12 | doha
# Processing Record 45 of Set 12 | savinskiy
# Processing Record 46 of Set 12 | korla
# Processing Record 47 of Set 12 | havre-saint-pierre
# Processing Record 48 of Set 12 | afrikanda
# Processing Record 49 of Set 12 | souillac
# Processing Record 50 of Set 12 | adrar
# Processing Record 1 of Set 13 | virginia beach
# Processing Record 2 of Set 13 | araouane
# Processing Record 3 of Set 13 | moron
# Processing Record 4 of Set 13 | chipinge
# Processing Record 5 of Set 13 | banyliv
# Processing Record 6 of Set 13 | puerto narino
# Processing Record 7 of Set 13 | karasjok
# Processing Record 8 of Set 13 | pochutla
# Processing Record 9 of Set 13 | mount pleasant
# Processing Record 10 of Set 13 | old saybrook
# Processing Record 11 of Set 13 | wasilla
# Processing Record 12 of Set 13 | kailua
# Processing Record 13 of Set 13 | vlore
# Processing Record 14 of Set 13 | buturlinovka
# Processing Record 15 of Set 13 | maputo
# Processing Record 16 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 17 of Set 13 | sidi bin nur
# Processing Record 18 of Set 13 | estevan
# Processing Record 19 of Set 13 | boyolangu
# Processing Record 20 of Set 13 | coruripe
# Processing Record 21 of Set 13 | valparaiso
# Processing Record 22 of Set 13 | at-bashi
# Processing Record 23 of Set 13 | prainha
# Processing Record 24 of Set 13 | riyadh
# Processing Record 25 of Set 13 | port blair
# Processing Record 26 of Set 13 | berbera
# Processing Record 27 of Set 13 | skelleftea
# Processing Record 28 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 29 of Set 13 | muravlenko
# Processing Record 30 of Set 13 | portalegre
# Processing Record 31 of Set 13 | bocas del toro
# Processing Record 32 of Set 13 | vestmannaeyjar
# Processing Record 33 of Set 13 | mago
# Processing Record 34 of Set 13 | riachao das neves
# Processing Record 35 of Set 13 | imeni poliny osipenko
# Processing Record 36 of Set 13 | moulins
# Processing Record 37 of Set 13 | margate
# Processing Record 38 of Set 13 | ushumun
# Processing Record 39 of Set 13 | sujiatun
# Processing Record 40 of Set 13 | shingu
# Processing Record 41 of Set 13 | ostersund
# Processing Record 42 of Set 13 | cururupu
# Processing Record 43 of Set 13 | orlik
# Processing Record 44 of Set 13 | neepawa
# Processing Record 45 of Set 13 | vicuna
# Processing Record 46 of Set 13 | rockhampton
# Processing Record 47 of Set 13 | uk
# City not found. Skipping...
# Processing Record 48 of Set 13 | west wendover
# Processing Record 49 of Set 13 | tigil
# Processing Record 50 of Set 13 | magui
# City not found. Skipping...
# Processing Record 1 of Set 14 | port hedland
# Processing Record 2 of Set 14 | bombay
# Processing Record 3 of Set 14 | shebekino
# Processing Record 4 of Set 14 | ha tinh
# Processing Record 5 of Set 14 | neuquen
# Processing Record 6 of Set 14 | grand-santi
# Processing Record 7 of Set 14 | emba
# Processing Record 8 of Set 14 | pierre
# Processing Record 9 of Set 14 | piacabucu
# Processing Record 10 of Set 14 | merauke
# Processing Record 11 of Set 14 | urumqi
# Processing Record 12 of Set 14 | puerto colombia
# Processing Record 13 of Set 14 | inirida
# Processing Record 14 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 15 of Set 14 | saint-georges
# Processing Record 16 of Set 14 | guayaramerin
# Processing Record 17 of Set 14 | avera
# Processing Record 18 of Set 14 | saint-leu
# Processing Record 19 of Set 14 | lugovskiy
# City not found. Skipping...
# Processing Record 20 of Set 14 | oktyabrskoye
# Processing Record 21 of Set 14 | pangkalanbuun
# Processing Record 22 of Set 14 | ribeira brava
# Processing Record 23 of Set 14 | mount isa
# Processing Record 24 of Set 14 | tatawin
# Processing Record 25 of Set 14 | husavik
# Processing Record 26 of Set 14 | nanchang
# Processing Record 27 of Set 14 | lluta
# Processing Record 28 of Set 14 | ajdabiya
# Processing Record 29 of Set 14 | ixtapa
# Processing Record 30 of Set 14 | banikoara
# Processing Record 31 of Set 14 | yulara
# Processing Record 32 of Set 14 | danane
# Processing Record 33 of Set 14 | aswan
# Processing Record 34 of Set 14 | eureka
# Processing Record 35 of Set 14 | zyryanka
# Processing Record 36 of Set 14 | madimba
# Processing Record 37 of Set 14 | tandil
# Processing Record 38 of Set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 39 of Set 14 | ongwediva
# Processing Record 40 of Set 14 | northam
# Processing Record 41 of Set 14 | estelle
# Processing Record 42 of Set 14 | san cristobal
# Processing Record 43 of Set 14 | santa rosa
# Processing Record 44 of Set 14 | ahuimanu
# Processing Record 45 of Set 14 | qandala
# Processing Record 46 of Set 14 | armacao dos buzios
# City not found. Skipping...
# Processing Record 47 of Set 14 | saint-francois
# Processing Record 48 of Set 14 | okhotsk
# Processing Record 49 of Set 14 | sungaipenuh
# Processing Record 50 of Set 14 | khuzdar
# Processing Record 1 of Set 15 | abnub
# Processing Record 2 of Set 15 | farafangana
# Processing Record 3 of Set 15 | kurilsk
# Processing Record 4 of Set 15 | divnomorskoye
# Processing Record 5 of Set 15 | khash
# Processing Record 6 of Set 15 | kalianget
# Processing Record 7 of Set 15 | barstow
# Processing Record 8 of Set 15 | honningsvag
# Processing Record 9 of Set 15 | ambon
# Processing Record 10 of Set 15 | warrnambool
# Processing Record 11 of Set 15 | bol
# Processing Record 12 of Set 15 | otane
# Processing Record 13 of Set 15 | mundo nuevo
# Processing Record 14 of Set 15 | aksarka
# Processing Record 15 of Set 15 | vercelli
# Processing Record 16 of Set 15 | penzance
# Processing Record 17 of Set 15 | bilibino
# Processing Record 18 of Set 15 | enid
# Processing Record 19 of Set 15 | balaipungut
# Processing Record 20 of Set 15 | mahur
# Processing Record 21 of Set 15 | aloleng
# Processing Record 22 of Set 15 | syumsi
# Processing Record 23 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 24 of Set 15 | kutum
# Processing Record 25 of Set 15 | clifton
# Processing Record 26 of Set 15 | tadine
# Processing Record 27 of Set 15 | kharp
# Processing Record 28 of Set 15 | pierreville
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 670

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Irtyshskiy      RU  58.3333   68.1333     19.80        89         100
# 1      Busselton      AU -33.6500  115.3333     66.04        83           0
# 2        Samarai      PG -10.6167  150.6667     79.95        82         100
# 3        Jojoima      SL   7.8792  -10.7878     83.50        28          42
# 4          Kapaa      US  22.0752 -159.3190     67.98        75          20
# 5      Ilulissat      GL  69.2167  -51.1000      6.82        47          75
# 6       Yar-Sale      RU  66.8333   70.8333    -11.60       100          78
# 7        Magadan      RU  59.5667  150.8000     -0.60        61          14
# 8  Mount Gambier      AU -37.8333  140.7667     58.91        82          40
# 9    Yellowknife      CA  62.4560 -114.3525    -11.58        86          75
#
#    Wind Speed Current Description
# 0        6.26     overcast clouds
# 1        7.56           clear sky
# 2        8.81     overcast clouds
# 3        0.31    scattered clouds
# 4        6.91          few clouds
# 5       11.50       broken clouds
# 6        3.42       broken clouds
# 7       12.28          few clouds
# 8        6.91    scattered clouds
# 9        6.91          light snow

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
