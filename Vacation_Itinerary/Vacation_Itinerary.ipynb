# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import ipywidgets as widgets

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    City_ID       City Country  Max Temp Current Description      Lat  \
# 0        1  Busselton      AU     66.04           clear sky -33.6500
# 1        2    Samarai      PG     79.95     overcast clouds -10.6167
# 2        4      Kapaa      US     67.98          few clouds  22.0752
# 3       12    Rikitea      PF     78.80     overcast clouds -23.1203
# 4       13      Vaini      TO     75.36          light rain -21.2000
#
#         Lng                           Hotel Name
# 0  115.3333              Observatory Guest House
# 1  150.6667                            Nuli Sapi
# 2 -159.3190  Sheraton Kauai Coconut Beach Resort
# 3 -134.9692                      People ThankYou
# 4 -175.2000                  Keleti Beach Resort

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Trip to Brazil.

# Grab the first hotel from the results and store the name.

brazil_vacation_df = vacation_df.loc[(vacation_df["Country"] == "BR")]
brazil_vacation_df.dropna()
# Out:
#      City_ID                 City Country  Max Temp Current Description  \
# 28        54                Conde      BR     85.46    scattered clouds
# 42        77               Trairi      BR     83.46       broken clouds
# 53       105      Arraial Do Cabo      BR     87.76        thunderstorm
# 59       116   Sao Felix Do Xingu      BR     86.58     overcast clouds
# 68       139               Castro      BR     75.16          light rain
# 75       161    Sao Joao Da Barra      BR     86.09    scattered clouds
# 76       162             Cidreira      BR     73.99     overcast clouds
# 84       180         Santa Isabel      BR     89.17     overcast clouds
# 100      219              Ibiruba      BR     75.76     overcast clouds
# 114      255            Itamaraca      BR     86.68    scattered clouds
# 115      257  Ouro Preto Do Oeste      BR     82.22     overcast clouds
# 133      286             Maragogi      BR     82.85     overcast clouds
# 134      291           Vila Velha      BR     84.15    scattered clouds
# 136      293          Paragominas      BR     79.79     overcast clouds
# 153      339                  Luz      BR     82.08    scattered clouds
# 162      353          Salinopolis      BR     79.72     overcast clouds
# 183      399             Alvorada      BR     83.95          light rain
# 213      481          Nortelandia      BR     89.69       broken clouds
# 236      525                Natal      BR     88.45          few clouds
# 239      529            Caravelas      BR     78.13     overcast clouds
# 256      569             Coruripe      BR     83.52     overcast clouds
# 258      572              Prainha      BR     82.29     overcast clouds
# 262      582    Riachao Das Neves      BR     81.93     overcast clouds
# 263      590             Cururupu      BR     81.77          light rain
# 269      605            Piacabucu      BR     83.16     overcast clouds
#
#          Lat      Lng                                         Hotel Name
# 28   -7.2597 -34.9075                                 Pousada Beija Flor
# 42   -3.2778 -39.2689                                     janelas do mar
# 53  -22.9661 -42.0278                                Pousada Porto Praia
# 59   -6.6447 -51.9950                                  Rio Xingu Camping
# 68  -24.7911 -50.0119                                     CHACARA BAILLY
# 75  -21.6403 -41.0511                            Pousada Porto De Canoas
# 76  -30.1811 -50.2056                                      Hotel Castelo
# 84  -23.3156 -46.2214                        Chácara Sombra do Altíssimo
# 100 -28.6275 -53.0897  Hotel Pitangueira - O melhor serviço pelo meno...
# 114  -7.7478 -34.8256                        Special K's Bed & Breakfast
# 115 -10.7481 -62.2158                                Graúna Resort Hotel
# 133  -9.0122 -35.2225           Salinas do Maragogi All Inclusive Resort
# 134 -20.3297 -40.2925                          Quality Suites Vila Velha
# 136  -2.9667 -47.4833                                              INOVA
# 153 -19.8014 -45.6856                                      Hotel Turista
# 162  -0.6136 -47.3561                 Salinas Park Resort Maçarico AP101
# 183 -12.4800 -49.1247                                Cristal Plaza Hotel
# 213 -14.4547 -56.8028                                      Hotel Karysmã
# 236  -5.7950 -35.2094                           Villa Park Hotel | Natal
# 239 -17.7125 -39.2481                             Pousada dos Navegantes
# 256 -10.1256 -36.1756                        Pousada e Hotel Litoral Sul
# 258  -1.8000 -53.4800                                         Casa Rocha
# 262 -11.7461 -44.9100                                         Casa Costa
# 263  -1.8283 -44.8683                                 POUSADA TRAVÉS'CIA
# 269 -10.4056 -36.4344                                     Piaçabuçu News

# %%
new_column_order = ["City_ID", "City", "Country", "Lat","Lng", "Max Temp", "Current Description"]

# %%
brazil_vacation_df = brazil_vacation_df[new_column_order]

# %%
brazil_vacation_df
# Out:
#      City_ID                 City Country      Lat      Lng  Max Temp  \
# 28        54                Conde      BR  -7.2597 -34.9075     85.46
# 42        77               Trairi      BR  -3.2778 -39.2689     83.46
# 53       105      Arraial Do Cabo      BR -22.9661 -42.0278     87.76
# 59       116   Sao Felix Do Xingu      BR  -6.6447 -51.9950     86.58
# 68       139               Castro      BR -24.7911 -50.0119     75.16
# 75       161    Sao Joao Da Barra      BR -21.6403 -41.0511     86.09
# 76       162             Cidreira      BR -30.1811 -50.2056     73.99
# 84       180         Santa Isabel      BR -23.3156 -46.2214     89.17
# 100      219              Ibiruba      BR -28.6275 -53.0897     75.76
# 114      255            Itamaraca      BR  -7.7478 -34.8256     86.68
# 115      257  Ouro Preto Do Oeste      BR -10.7481 -62.2158     82.22
# 133      286             Maragogi      BR  -9.0122 -35.2225     82.85
# 134      291           Vila Velha      BR -20.3297 -40.2925     84.15
# 136      293          Paragominas      BR  -2.9667 -47.4833     79.79
# 153      339                  Luz      BR -19.8014 -45.6856     82.08
# 162      353          Salinopolis      BR  -0.6136 -47.3561     79.72
# 183      399             Alvorada      BR -12.4800 -49.1247     83.95
# 213      481          Nortelandia      BR -14.4547 -56.8028     89.69
# 236      525                Natal      BR  -5.7950 -35.2094     88.45
# 239      529            Caravelas      BR -17.7125 -39.2481     78.13
# 256      569             Coruripe      BR -10.1256 -36.1756     83.52
# 258      572              Prainha      BR  -1.8000 -53.4800     82.29
# 262      582    Riachao Das Neves      BR -11.7461 -44.9100     81.93
# 263      590             Cururupu      BR  -1.8283 -44.8683     81.77
# 269      605            Piacabucu      BR -10.4056 -36.4344     83.16
#
#     Current Description
# 28     scattered clouds
# 42        broken clouds
# 53         thunderstorm
# 59      overcast clouds
# 68           light rain
# 75     scattered clouds
# 76      overcast clouds
# 84      overcast clouds
# 100     overcast clouds
# 114    scattered clouds
# 115     overcast clouds
# 133     overcast clouds
# 134    scattered clouds
# 136     overcast clouds
# 153    scattered clouds
# 162     overcast clouds
# 183          light rain
# 213       broken clouds
# 236          few clouds
# 239     overcast clouds
# 256     overcast clouds
# 258     overcast clouds
# 262     overcast clouds
# 263          light rain
# 269     overcast clouds

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

start = float(input("What is the City_ID from BR List do you like to start? "))
stop1 = float(input("What is your first stop City_ID from BR List do you would like for your trip? "))
stop2 = float(input("What is your second stop City_ID from BR List do you would like for your trip? "))
stop3 = float(input("What is your thirth stop City_ID from BR List do you would like for your trip? "))
end = float(input("What is your last stop city_ID from BR List do you would like for your trip? "))
# Out:
# What is the City_ID from BR List do you like to start? 54
# What is your first stop City_ID from BR List do you would like for your trip? 77
# What is your second stop City_ID from BR List do you would like for your trip? 105
# What is your thirth stop City_ID from BR List do you would like for your trip? 116
# What is your last stop city_ID from BR List do you would like for your trip? 139

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.

vacation_start = brazil_vacation_df.loc[(brazil_vacation_df["City_ID"] == stop1)]
vacation_start = vacation_start.iloc[0]

vacation_stop1 = brazil_vacation_df.loc[(brazil_vacation_df["City_ID"] == stop2)]
vacation_stop1 = vacation_stop1.iloc[0]

vacation_stop2 = brazil_vacation_df.loc[(brazil_vacation_df["City_ID"] == stop3)]
vacation_stop2 = vacation_stop2.iloc[0]

vacation_stop3 = brazil_vacation_df.loc[(brazil_vacation_df["City_ID"] == end)]
vacation_stop3 = vacation_stop3.iloc[0]

vacation_end = brazil_vacation_df.loc[(brazil_vacation_df["City_ID"] <= end)]
vacation_end = vacation_end.iloc[0] 
                                     
print("Your Starting Destination is " + vacation_start["City"] + ", " + vacation_start["Country"])
print("Your Frist Stop is " + vacation_stop1["City"] + ", " + vacation_stop1["Country"])
print("Your Second Stop is " + vacation_stop2["City"] + ", " + vacation_stop2["Country"])                                     
print("Your Thirth Stop is " + vacation_stop3["City"] + ", " + vacation_stop3["Country"])                                     
print("Your Last Stop in your vacation is " + vacation_end["City"] + ", " + vacation_end["Country"])
# Out:
# Your Starting Destination is Trairi, BR
# Your Frist Stop is Arraial Do Cabo, BR
# Your Second Stop is Sao Felix Do Xingu, BR
# Your Thirth Stop is Castro, BR
# Your Last Stop in your vacation is Conde, BR

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start[["Lat", "Lng"]]
print(start)
# Out:
# Lat    -3.2778
# Lng   -39.2689
# Name: 42, dtype: object

# %%
stop1 = vacation_stop1[["Lat", "Lng"]]
print(stop1)
# Out:
# Lat   -22.9661
# Lng   -42.0278
# Name: 53, dtype: object

# %%
stop2 = vacation_stop2[["Lat", "Lng"]]
print(stop2)
# Out:
# Lat   -6.6447
# Lng   -51.995
# Name: 59, dtype: object

# %%
stop3 = vacation_stop3[["Lat", "Lng"]]
print(stop3)
# Out:
# Lat   -24.7911
# Lng   -50.0119
# Name: 68, dtype: object

# %%
end = vacation_end[["Lat", "Lng"]]
print(end)
# Out:
# Lat    -7.2597
# Lng   -34.9075
# Name: 28, dtype: object

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

import gmaps
import gmaps.datasets
gmaps.configure(api_key=g_key)

start = (20.7, -105.2)
stop1 = (17.48, -91.43)
stop2 = (27.98, -114.06)
stop3 = (23.17, -97.95)
end = (30.85, -116.07)

fig = gmaps.figure()
sart2end_via_stops = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2, stop3],
        travel_mode='DRIVING')
fig.add_layer(sart2end_via_stops)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.

brazil_vacation_df = pd.concat([brazil_vacation_df],ignore_index=True)
brazil_vacation_df
# Out:
#     City_ID                 City Country      Lat      Lng  Max Temp  \
# 0        54                Conde      BR  -7.2597 -34.9075     85.46
# 1        77               Trairi      BR  -3.2778 -39.2689     83.46
# 2       105      Arraial Do Cabo      BR -22.9661 -42.0278     87.76
# 3       116   Sao Felix Do Xingu      BR  -6.6447 -51.9950     86.58
# 4       139               Castro      BR -24.7911 -50.0119     75.16
# 5       161    Sao Joao Da Barra      BR -21.6403 -41.0511     86.09
# 6       162             Cidreira      BR -30.1811 -50.2056     73.99
# 7       180         Santa Isabel      BR -23.3156 -46.2214     89.17
# 8       219              Ibiruba      BR -28.6275 -53.0897     75.76
# 9       255            Itamaraca      BR  -7.7478 -34.8256     86.68
# 10      257  Ouro Preto Do Oeste      BR -10.7481 -62.2158     82.22
# 11      286             Maragogi      BR  -9.0122 -35.2225     82.85
# 12      291           Vila Velha      BR -20.3297 -40.2925     84.15
# 13      293          Paragominas      BR  -2.9667 -47.4833     79.79
# 14      339                  Luz      BR -19.8014 -45.6856     82.08
# 15      353          Salinopolis      BR  -0.6136 -47.3561     79.72
# 16      399             Alvorada      BR -12.4800 -49.1247     83.95
# 17      481          Nortelandia      BR -14.4547 -56.8028     89.69
# 18      525                Natal      BR  -5.7950 -35.2094     88.45
# 19      529            Caravelas      BR -17.7125 -39.2481     78.13
# 20      569             Coruripe      BR -10.1256 -36.1756     83.52
# 21      572              Prainha      BR  -1.8000 -53.4800     82.29
# 22      582    Riachao Das Neves      BR -11.7461 -44.9100     81.93
# 23      590             Cururupu      BR  -1.8283 -44.8683     81.77
# 24      605            Piacabucu      BR -10.4056 -36.4344     83.16
#
#    Current Description
# 0     scattered clouds
# 1        broken clouds
# 2         thunderstorm
# 3      overcast clouds
# 4           light rain
# 5     scattered clouds
# 6      overcast clouds
# 7      overcast clouds
# 8      overcast clouds
# 9     scattered clouds
# 10     overcast clouds
# 11     overcast clouds
# 12    scattered clouds
# 13     overcast clouds
# 14    scattered clouds
# 15     overcast clouds
# 16          light rain
# 17       broken clouds
# 18          few clouds
# 19     overcast clouds
# 20     overcast clouds
# 21     overcast clouds
# 22     overcast clouds
# 23          light rain
# 24     overcast clouds

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
mark_info = [info_box_template.format(**row) for index, row in brazil_vacation_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = brazil_vacation_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
city_mark = brazil_vacation_df["City"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=mark_info)

fig.add_layer(marker_layer)

# %%
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
